# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 618

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# OpenWeatherMap API Key
#api_key = api_keys.api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key +"&q="

#Cities weather data frame
Cities_DF = pd.DataFrame({"City":cities})
Cities_DF["Temperature(F)"] =""
Cities_DF["Humidity(%)"] =""
Cities_DF["Cloudiness(%)"] =""
Cities_DF["Wind Speed(mph)"] =""
Cities_DF["Latitude"]=""
Cities_DF["Longitude"]=""
Cities_DF["Date"]=""
Cities_DF.head()
print("Beginning Data Retrieval")
print("------------------------")

for index, row in Cities_DF.iterrows():
    
    time.sleep(.8)
    city =row["City"]
    response = requests.get(url+city)
    city_weather = response.json()
    print(f"Processing Record {index} | {city}")
    city_weather_url =response.url
    #print(response.url)

    
    try:
        Cities_DF.loc[index,"Temperature(F)"]=city_weather['main']['temp']
        Cities_DF.loc[index,"Humidity(%)"]=city_weather['main']['humidity']
        Cities_DF.loc[index,"Cloudiness(%)"]=city_weather['clouds']['all']
        Cities_DF.loc[index,"Wind Speed(mph)"]=city_weather['wind']['speed']
        Cities_DF.loc[index,"Latitude"]=city_weather['coord']['lat']
        Cities_DF.loc[index,"Longitude"]=city_weather["coord"]['lon']
        Cities_DF.loc[index,"Date"]=city_weather["dt"]
        
    except (KeyError, IndexError):
        print(f"City not found... skipping.")

print("------------------------")
print("Data Retrieval Complete")
print("------------------------")

print(Cities_DF)
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 0 | vaini
# Processing Record 1 | saleaula
# City not found... skipping.
# Processing Record 2 | korla
# Processing Record 3 | belaya gora
# Processing Record 4 | cidreira
# Processing Record 5 | saint-philippe
# Processing Record 6 | norman wells
# Processing Record 7 | tsihombe
# City not found... skipping.
# Processing Record 8 | puerto narino
# Processing Record 9 | busselton
# Processing Record 10 | nikolskoye
# Processing Record 11 | aberdeen
# Processing Record 12 | sur
# Processing Record 13 | male
# Processing Record 14 | isangel
# Processing Record 15 | lebu
# Processing Record 16 | ankazoabo
# Processing Record 17 | illoqqortoormiut
# City not found... skipping.
# Processing Record 18 | cobija
# Processing Record 19 | mataura
# Processing Record 20 | longyearbyen
# Processing Record 21 | mullaitivu
# City not found... skipping.
# Processing Record 22 | havre-saint-pierre
# Processing Record 23 | port alfred
# Processing Record 24 | mar del plata
# Processing Record 25 | hilo
# Processing Record 26 | bluff
# Processing Record 27 | general roca
# Processing Record 28 | tolbazy
# Processing Record 29 | butaritari
# Processing Record 30 | punta arenas
# Processing Record 31 | coquimbo
# Processing Record 32 | skalistyy
# City not found... skipping.
# Processing Record 33 | grand river south east
# City not found... skipping.
# Processing Record 34 | dese
# Processing Record 35 | jati
# Processing Record 36 | hermanus
# Processing Record 37 | hamilton
# Processing Record 38 | new norfolk
# Processing Record 39 | baruun-urt
# Processing Record 40 | dudinka
# Processing Record 41 | ponta do sol
# Processing Record 42 | vila franca do campo
# Processing Record 43 | attawapiskat
# City not found... skipping.
# Processing Record 44 | atuona
# Processing Record 45 | mumford
# Processing Record 46 | aguas vermelhas
# Processing Record 47 | cape town
# Processing Record 48 | puerto ayora
# Processing Record 49 | albany
# Processing Record 50 | porbandar
# Processing Record 51 | shieli
# Processing Record 52 | augustow
# Processing Record 53 | balykshi
# Processing Record 54 | carnarvon
# Processing Record 55 | barrow
# Processing Record 56 | te anau
# Processing Record 57 | ushuaia
# Processing Record 58 | skibbereen
# Processing Record 59 | lavrentiya
# Processing Record 60 | asau
# Processing Record 61 | listvyagi
# Processing Record 62 | avarua
# Processing Record 63 | veraval
# Processing Record 64 | obigarm
# Processing Record 65 | hithadhoo
# Processing Record 66 | payson
# Processing Record 67 | carnot
# Processing Record 68 | valleyview
# Processing Record 69 | san cristobal
# Processing Record 70 | srednekolymsk
# Processing Record 71 | kaeo
# Processing Record 72 | saskylakh
# Processing Record 73 | castro
# Processing Record 74 | bredasdorp
# Processing Record 75 | sinjah
# City not found... skipping.
# Processing Record 76 | mys shmidta
# City not found... skipping.
# Processing Record 77 | aswan
# Processing Record 78 | murray bridge
# Processing Record 79 | staropesterevo
# Processing Record 80 | deniliquin
# Processing Record 81 | jamestown
# Processing Record 82 | severo-kurilsk
# Processing Record 83 | esperance
# Processing Record 84 | billings
# Processing Record 85 | taolanaro
# City not found... skipping.
# Processing Record 86 | kruisfontein
# Processing Record 87 | amderma
# City not found... skipping.
# Processing Record 88 | kaitangata
# Processing Record 89 | yafran
# Processing Record 90 | barentsburg
# City not found... skipping.
# Processing Record 91 | lorengau
# Processing Record 92 | nanortalik
# Processing Record 93 | mount gambier
# Processing Record 94 | chokurdakh
# Processing Record 95 | nome
# Processing Record 96 | kapaa
# Processing Record 97 | yellowknife
# Processing Record 98 | aranos
# Processing Record 99 | codrington
# Processing Record 100 | nouadhibou
# Processing Record 101 | sawtell
# Processing Record 102 | skeldon
# Processing Record 103 | clarence town
# Processing Record 104 | nizhneyansk
# City not found... skipping.
# Processing Record 105 | bolungarvik
# City not found... skipping.
# Processing Record 106 | tuktoyaktuk
# Processing Record 107 | san patricio
# Processing Record 108 | sisimiut
# Processing Record 109 | tasiilaq
# Processing Record 110 | kodiak
# Processing Record 111 | mattru
# Processing Record 112 | mitu
# Processing Record 113 | saint-joseph
# Processing Record 114 | togur
# Processing Record 115 | mendi
# Processing Record 116 | rikitea
# Processing Record 117 | andselv
# City not found... skipping.
# Processing Record 118 | saint anthony
# Processing Record 119 | nyagan
# Processing Record 120 | amot
# Processing Record 121 | christchurch
# Processing Record 122 | cayenne
# Processing Record 123 | bathsheba
# Processing Record 124 | upernavik
# Processing Record 125 | meulaboh
# Processing Record 126 | east london
# Processing Record 127 | bethel
# Processing Record 128 | praya
# Processing Record 129 | garissa
# Processing Record 130 | dingle
# Processing Record 131 | bowen
# Processing Record 132 | lompoc
# Processing Record 133 | solnechnyy
# Processing Record 134 | jaipur hat
# City not found... skipping.
# Processing Record 135 | vanimo
# Processing Record 136 | seoul
# Processing Record 137 | tumannyy
# City not found... skipping.
# Processing Record 138 | phuket
# Processing Record 139 | pangnirtung
# Processing Record 140 | ahipara
# Processing Record 141 | chuy
# Processing Record 142 | geraldton
# Processing Record 143 | bambanglipuro
# Processing Record 144 | potgietersrus
# City not found... skipping.
# Processing Record 145 | crab hill
# City not found... skipping.
# Processing Record 146 | stepnogorsk
# Processing Record 147 | sainte-martine
# Processing Record 148 | yerbogachen
# Processing Record 149 | ariquemes
# Processing Record 150 | margate
# Processing Record 151 | cabo san lucas
# Processing Record 152 | mumbwa
# Processing Record 153 | meadow lake
# Processing Record 154 | malwan
# City not found... skipping.
# Processing Record 155 | komsomolskiy
# Processing Record 156 | la macarena
# Processing Record 157 | ucluelet
# Processing Record 158 | fairbanks
# Processing Record 159 | darnah
# Processing Record 160 | ilulissat
# Processing Record 161 | malanje
# Processing Record 162 | atar
# Processing Record 163 | gamba
# Processing Record 164 | sentyabrskiy
# City not found... skipping.
# Processing Record 165 | logrono
# Processing Record 166 | qaanaaq
# Processing Record 167 | ust-tsilma
# Processing Record 168 | doaba
# Processing Record 169 | palabuhanratu
# City not found... skipping.
# Processing Record 170 | barmer
# Processing Record 171 | alice springs
# Processing Record 172 | maldonado
# Processing Record 173 | gazli
# Processing Record 174 | katsuura
# Processing Record 175 | marrakesh
# Processing Record 176 | hellvik
# Processing Record 177 | urumqi
# Processing Record 178 | victoria
# Processing Record 179 | panaba
# Processing Record 180 | maniitsoq
# Processing Record 181 | linhares
# Processing Record 182 | falealupo
# City not found... skipping.
# Processing Record 183 | sijunjung
# Processing Record 184 | lazaro cardenas
# Processing Record 185 | caravelas
# Processing Record 186 | ribeira grande
# Processing Record 187 | kalmunai
# Processing Record 188 | samarai
# Processing Record 189 | constitucion
# Processing Record 190 | labutta
# City not found... skipping.
# Processing Record 191 | shimoda
# Processing Record 192 | souillac
# Processing Record 193 | khatanga
# Processing Record 194 | mogadishu
# Processing Record 195 | hobart
# Processing Record 196 | belushya guba
# City not found... skipping.
# Processing Record 197 | awjilah
# Processing Record 198 | srandakan
# Processing Record 199 | faya
# Processing Record 200 | airai
# Processing Record 201 | faanui
# Processing Record 202 | duz
# City not found... skipping.
# Processing Record 203 | pacific grove
# Processing Record 204 | tupik
# Processing Record 205 | port hardy
# Processing Record 206 | warqla
# City not found... skipping.
# Processing Record 207 | nyurba
# Processing Record 208 | santa maria
# Processing Record 209 | arraial do cabo
# Processing Record 210 | natal
# Processing Record 211 | launceston
# Processing Record 212 | alyangula
# Processing Record 213 | pangkalanbuun
# Processing Record 214 | dikson
# Processing Record 215 | chengde
# Processing Record 216 | dong hoi
# Processing Record 217 | sioux lookout
# Processing Record 218 | hawick
# Processing Record 219 | benguela
# Processing Record 220 | chipinge
# Processing Record 221 | provideniya
# Processing Record 222 | svetlyy
# Processing Record 223 | juifang
# City not found... skipping.
# Processing Record 224 | bengkulu
# Processing Record 225 | gari
# Processing Record 226 | ryotsu
# Processing Record 227 | mizan teferi
# Processing Record 228 | partyzany
# Processing Record 229 | reyes
# Processing Record 230 | dhupgari
# Processing Record 231 | gayny
# Processing Record 232 | katherine
# Processing Record 233 | ust-tarka
# Processing Record 234 | sri aman
# Processing Record 235 | mahebourg
# Processing Record 236 | starokucherganovka
# Processing Record 237 | grand gaube
# Processing Record 238 | marzuq
# Processing Record 239 | pangody
# Processing Record 240 | vardo
# Processing Record 241 | thompson
# Processing Record 242 | torbay
# Processing Record 243 | saint simons
# Processing Record 244 | stargard szczecinski
# Processing Record 245 | san agustin acasaguastlan
# Processing Record 246 | fortuna
# Processing Record 247 | acarau
# Processing Record 248 | price
# Processing Record 249 | thinadhoo
# Processing Record 250 | tual
# Processing Record 251 | manggar
# Processing Record 252 | palu
# Processing Record 253 | san vicente
# Processing Record 254 | kijang
# Processing Record 255 | alofi
# Processing Record 256 | ruatoria
# City not found... skipping.
# Processing Record 257 | hobyo
# Processing Record 258 | haines junction
# Processing Record 259 | hasilpur
# Processing Record 260 | tigil
# Processing Record 261 | mitsamiouli
# Processing Record 262 | orsk
# Processing Record 263 | vestmannaeyjar
# Processing Record 264 | coihaique
# Processing Record 265 | leh
# Processing Record 266 | dawei
# Processing Record 267 | arinos
# Processing Record 268 | kavaratti
# Processing Record 269 | sorong
# Processing Record 270 | burns lake
# Processing Record 271 | manzil tamim
# City not found... skipping.
# Processing Record 272 | goderich
# Processing Record 273 | lata
# Processing Record 274 | bambous virieux
# Processing Record 275 | beloha
# Processing Record 276 | arica
# Processing Record 277 | oiba
# Processing Record 278 | orlik
# Processing Record 279 | kahului
# Processing Record 280 | clyde river
# Processing Record 281 | luwuk
# Processing Record 282 | bosaso
# Processing Record 283 | anadyr
# Processing Record 284 | dobele
# Processing Record 285 | iskandar
# Processing Record 286 | praia da vitoria
# Processing Record 287 | zheleznodorozhnyy
# Processing Record 288 | abha
# Processing Record 289 | aquin
# Processing Record 290 | matipo
# Processing Record 291 | berezayka
# Processing Record 292 | adigeni
# Processing Record 293 | honningsvag
# Processing Record 294 | kamaishi
# Processing Record 295 | akdagmadeni
# Processing Record 296 | turayf
# Processing Record 297 | yuci
# Processing Record 298 | iqaluit
# Processing Record 299 | mangalia
# Processing Record 300 | taltal
# Processing Record 301 | moctezuma
# Processing Record 302 | ikwiriri
# Processing Record 303 | teguise
# Processing Record 304 | gladstone
# Processing Record 305 | okhotsk
# Processing Record 306 | port lincoln
# Processing Record 307 | poum
# Processing Record 308 | gillette
# Processing Record 309 | sitka
# Processing Record 310 | touros
# Processing Record 311 | progreso
# Processing Record 312 | chagda
# City not found... skipping.
# Processing Record 313 | baykit
# Processing Record 314 | san jeronimo
# Processing Record 315 | egvekinot
# Processing Record 316 | nizhniy tsasuchey
# Processing Record 317 | georgetown
# Processing Record 318 | cap-aux-meules
# Processing Record 319 | shubarshi
# Processing Record 320 | quatre cocos
# Processing Record 321 | ahuimanu
# Processing Record 322 | aklavik
# Processing Record 323 | flinders
# Processing Record 324 | artyk
# City not found... skipping.
# Processing Record 325 | krasnoselkup
# Processing Record 326 | presque isle
# Processing Record 327 | taksimo
# Processing Record 328 | valkla
# Processing Record 329 | pitea
# Processing Record 330 | la ronge
# Processing Record 331 | dondo
# Processing Record 332 | barabai
# Processing Record 333 | nantucket
# Processing Record 334 | finspang
# Processing Record 335 | rongcheng
# Processing Record 336 | polyarnyy
# Processing Record 337 | pinega
# Processing Record 338 | muswellbrook
# Processing Record 339 | koumac
# Processing Record 340 | khani
# Processing Record 341 | cherskiy
# Processing Record 342 | erdenet
# Processing Record 343 | takab
# Processing Record 344 | we
# City not found... skipping.
# Processing Record 345 | kisangani
# Processing Record 346 | saint george
# Processing Record 347 | dolbeau
# City not found... skipping.
# Processing Record 348 | tazovskiy
# Processing Record 349 | santa rosa
# Processing Record 350 | elko
# Processing Record 351 | mrirt
# City not found... skipping.
# Processing Record 352 | ponta delgada
# Processing Record 353 | cockburn town
# Processing Record 354 | cumberland
# Processing Record 355 | totma
# Processing Record 356 | takestan
# Processing Record 357 | show low
# Processing Record 358 | comodoro rivadavia
# Processing Record 359 | pauini
# Processing Record 360 | narsaq
# Processing Record 361 | meridian
# Processing Record 362 | santa rosalia
# Processing Record 363 | belmonte
# Processing Record 364 | altamira
# Processing Record 365 | puerto carreno
# Processing Record 366 | sola
# Processing Record 367 | the valley
# Processing Record 368 | kemin
# Processing Record 369 | paracuru
# Processing Record 370 | richards bay
# Processing Record 371 | cabedelo
# Processing Record 372 | taoudenni
# Processing Record 373 | tiksi
# Processing Record 374 | adrar
# Processing Record 375 | flagstaff
# Processing Record 376 | kangaatsiaq
# Processing Record 377 | abu zabad
# Processing Record 378 | bilibino
# Processing Record 379 | lafiagi
# Processing Record 380 | fayaoue
# Processing Record 381 | yumen
# Processing Record 382 | xingyi
# Processing Record 383 | bom jesus
# Processing Record 384 | los llanos de aridane
# Processing Record 385 | monywa
# Processing Record 386 | shchuchye
# City not found... skipping.
# Processing Record 387 | fare
# Processing Record 388 | bodaybo
# Processing Record 389 | sao joao da barra
# Processing Record 390 | bay roberts
# Processing Record 391 | gioia tauro
# Processing Record 392 | yulara
# Processing Record 393 | port elizabeth
# Processing Record 394 | great yarmouth
# Processing Record 395 | warrnambool
# Processing Record 396 | vung tau
# Processing Record 397 | pochutla
# Processing Record 398 | omboue
# Processing Record 399 | deputatskiy
# Processing Record 400 | anloga
# Processing Record 401 | tautira
# Processing Record 402 | jiangyou
# Processing Record 403 | pevek
# Processing Record 404 | nagato
# Processing Record 405 | waingapu
# Processing Record 406 | chapais
# Processing Record 407 | aborlan
# Processing Record 408 | port-gentil
# Processing Record 409 | konakovo
# Processing Record 410 | tuatapere
# Processing Record 411 | grindavik
# Processing Record 412 | hunza
# City not found... skipping.
# Processing Record 413 | vao
# Processing Record 414 | general pico
# Processing Record 415 | jalhay
# Processing Record 416 | puerto baquerizo moreno
# Processing Record 417 | porto de moz
# Processing Record 418 | kemijarvi
# Processing Record 419 | ojinaga
# Processing Record 420 | kosh-agach
# Processing Record 421 | lamu
# Processing Record 422 | kashan
# Processing Record 423 | laukaa
# Processing Record 424 | viedma
# Processing Record 425 | aksu
# Processing Record 426 | virginia beach
# Processing Record 427 | alta floresta
# Processing Record 428 | sao filipe
# Processing Record 429 | brae
# Processing Record 430 | muisne
# Processing Record 431 | biak
# Processing Record 432 | qandala
# Processing Record 433 | ayagoz
# Processing Record 434 | skelleftea
# Processing Record 435 | saint-pierre
# Processing Record 436 | sakaiminato
# Processing Record 437 | elizabeth city
# Processing Record 438 | norristown
# Processing Record 439 | ndele
# Processing Record 440 | yar-sale
# Processing Record 441 | kyra
# Processing Record 442 | batagay-alyta
# Processing Record 443 | zinder
# Processing Record 444 | chaman
# Processing Record 445 | hofn
# Processing Record 446 | mecca
# Processing Record 447 | peniche
# Processing Record 448 | djambala
# Processing Record 449 | hambantota
# Processing Record 450 | andapa
# Processing Record 451 | corn island
# Processing Record 452 | west wendover
# Processing Record 453 | rungata
# City not found... skipping.
# Processing Record 454 | vaitape
# Processing Record 455 | kalianget
# Processing Record 456 | saint-augustin
# Processing Record 457 | santiago de cuba
# Processing Record 458 | bandundu
# Processing Record 459 | marcona
# City not found... skipping.
# Processing Record 460 | henties bay
# Processing Record 461 | port said
# Processing Record 462 | talnakh
# Processing Record 463 | qaqortoq
# Processing Record 464 | bemidji
# Processing Record 465 | vitina
# Processing Record 466 | fort nelson
# Processing Record 467 | fort saint john
# City not found... skipping.
# Processing Record 468 | akyab
# Processing Record 469 | boa vista
# Processing Record 470 | da nang
# Processing Record 471 | preili
# Processing Record 472 | samsun
# Processing Record 473 | aloleng
# Processing Record 474 | kavieng
# Processing Record 475 | ranot
# Processing Record 476 | san isidro
# Processing Record 477 | esna
# Processing Record 478 | campbell river
# Processing Record 479 | knarvik
# Processing Record 480 | saryshagan
# City not found... skipping.
# Processing Record 481 | bubanza
# Processing Record 482 | coffs harbour
# Processing Record 483 | colatina
# Processing Record 484 | darab
# Processing Record 485 | waipawa
# Processing Record 486 | pasaje
# Processing Record 487 | visnes
# Processing Record 488 | camden
# Processing Record 489 | olafsvik
# Processing Record 490 | petrolia
# Processing Record 491 | pasighat
# Processing Record 492 | aksehir
# Processing Record 493 | tokur
# Processing Record 494 | ulladulla
# Processing Record 495 | cordoba
# Processing Record 496 | culebra
# Processing Record 497 | lincoln
# Processing Record 498 | lanigan
# Processing Record 499 | vila velha
# Processing Record 500 | namtsy
# Processing Record 501 | south lake tahoe
# Processing Record 502 | denpasar
# Processing Record 503 | moree
# Processing Record 504 | guanica
# Processing Record 505 | sandwick
# Processing Record 506 | den helder
# Processing Record 507 | whitehorse
# Processing Record 508 | rabat
# Processing Record 509 | barabinsk
# Processing Record 510 | san julian
# Processing Record 511 | wajima
# Processing Record 512 | tricase
# Processing Record 513 | vostok
# Processing Record 514 | russell
# Processing Record 515 | tshikapa
# Processing Record 516 | college
# Processing Record 517 | tamandare
# Processing Record 518 | itarema
# Processing Record 519 | banda aceh
# Processing Record 520 | vila do maio
# Processing Record 521 | eyl
# Processing Record 522 | ola
# Processing Record 523 | iquitos
# Processing Record 524 | mentok
# City not found... skipping.
# Processing Record 525 | ulaangom
# Processing Record 526 | ancud
# Processing Record 527 | nabire
# Processing Record 528 | lhokseumawe
# Processing Record 529 | tra vinh
# Processing Record 530 | mahibadhoo
# Processing Record 531 | rantepao
# Processing Record 532 | klaksvik
# Processing Record 533 | sao jose da coroa grande
# Processing Record 534 | doctor pedro p. pena
# City not found... skipping.
# Processing Record 535 | guerrero negro
# Processing Record 536 | heide
# Processing Record 537 | carutapera
# Processing Record 538 | kirensk
# Processing Record 539 | kirpilskaya
# Processing Record 540 | lagoa
# Processing Record 541 | liverpool
# Processing Record 542 | hami
# Processing Record 543 | port hedland
# Processing Record 544 | camacupa
# Processing Record 545 | cairns
# Processing Record 546 | laguna
# Processing Record 547 | dunedin
# Processing Record 548 | dalby
# Processing Record 549 | victoria point
# Processing Record 550 | martonvasar
# Processing Record 551 | le port
# Processing Record 552 | aylmer
# Processing Record 553 | galiwinku
# City not found... skipping.
# Processing Record 554 | maragheh
# Processing Record 555 | koulikoro
# Processing Record 556 | paita
# Processing Record 557 | moose factory
# Processing Record 558 | labrea
# Processing Record 559 | chuguyevka
# Processing Record 560 | batticaloa
# Processing Record 561 | paamiut
# Processing Record 562 | suluq
# Processing Record 563 | mabaruma
# Processing Record 564 | bongandanga
# Processing Record 565 | camalu
# Processing Record 566 | sovetskiy
# Processing Record 567 | oriximina
# Processing Record 568 | chiang khong
# Processing Record 569 | senador jose porfirio
# Processing Record 570 | pakxan
# Processing Record 571 | putina
# Processing Record 572 | gambela
# Processing Record 573 | maralal
# Processing Record 574 | verkhoyansk
# Processing Record 575 | sao desiderio
# Processing Record 576 | almaznyy
# Processing Record 577 | maymanak
# City not found... skipping.
# Processing Record 578 | nicolas bravo
# Processing Record 579 | henderson
# Processing Record 580 | wahran
# City not found... skipping.
# Processing Record 581 | panji
# Processing Record 582 | bud
# Processing Record 583 | almeirim
# Processing Record 584 | hasaki
# Processing Record 585 | gotsu
# Processing Record 586 | sibolga
# Processing Record 587 | rexburg
# Processing Record 588 | clinton
# Processing Record 589 | sinazongwe
# Processing Record 590 | pudozh
# Processing Record 591 | luganville
# Processing Record 592 | port keats
# Processing Record 593 | muyezerskiy
# Processing Record 594 | tilichiki
# Processing Record 595 | dasoguz
# Processing Record 596 | zandvoort
# Processing Record 597 | salalah
# Processing Record 598 | mme
# City not found... skipping.
# Processing Record 599 | ambon
# Processing Record 600 | zhigansk
# Processing Record 601 | varnamo
# Processing Record 602 | namatanai
# Processing Record 603 | arzgir
# Processing Record 604 | lasa
# Processing Record 605 | cravo norte
# Processing Record 606 | guarapari
# Processing Record 607 | saint andrews
# Processing Record 608 | ixtapa
# Processing Record 609 | tabas
# Processing Record 610 | walvis bay
# Processing Record 611 | farmington
# Processing Record 612 | kyren
# Processing Record 613 | ilebo
# Processing Record 614 | uk
# City not found... skipping.
# Processing Record 615 | fredericksburg
# Processing Record 616 | villa maria
# Processing Record 617 | casa branca
# ------------------------
# Data Retrieval Complete
# ------------------------
#                City Temperature(F) Humidity(%) Cloudiness(%) Wind Speed(mph)  \
# 0             vaini          82.56          83            20            11.5
# 1          saleaula
# 2             korla          25.41          52            65            2.73
# 3       belaya gora         -19.59          97           100            2.37
# 4          cidreira          68.83          77            43           19.86
# ..              ...            ...         ...           ...             ...
# 613           ilebo          71.58          95           100             1.1
# 614              uk
# 615  fredericksburg          53.02          47             1            1.99
# 616     villa maria          78.26          40            93            7.38
# 617     casa branca          83.23          65            30            7.99
#
#     Latitude Longitude        Date
# 0      -21.2    -175.2  1638567362
# 1
# 2    41.7597   86.1469  1638567364
# 3    68.5333  146.4167  1638567365
# 4   -30.1811  -50.2056  1638567366
# ..       ...       ...         ...
# 613  -4.3167   20.5833  1638568014
# 614
# 615  38.3032  -77.4605  1638568016
# 616 -32.4075  -63.2402  1638568018
# 617 -21.7739  -47.0864  1638568019
#
# [618 rows x 8 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
Cities_DF.dropna(axis=0, inplace=True)

Cities_DF.to_csv('city_data_output.csv')
Cities_DF.head()
# Out:
#           City Temperature(F) Humidity(%) Cloudiness(%) Wind Speed(mph)  \
# 0        vaini          82.56          83            20            11.5
# 1     saleaula
# 2        korla          25.41          52            65            2.73
# 3  belaya gora         -19.59          97           100            2.37
# 4     cidreira          68.83          77            43           19.86
#
#   Latitude Longitude        Date
# 0    -21.2    -175.2  1638567362
# 1
# 2  41.7597   86.1469  1638567364
# 3  68.5333  146.4167  1638567365
# 4 -30.1811  -50.2056  1638567366

# %%
Cities_DF["Lat"] = pd.to_numeric(Cities_DF["Latitude"],errors='coerce')
Cities_DF["Lng"] = pd.to_numeric(Cities_DF["Longitude"],errors='coerce')
Cities_DF["Max Temp(%)"] = pd.to_numeric(Cities_DF["Temperature(F)"],errors='coerce')
Cities_DF["Humidity"] = pd.to_numeric(Cities_DF["Humidity(%)"],errors='coerce')
Cities_DF["Cloudiness(F)"] = pd.to_numeric(Cities_DF["Cloudiness(%)"],errors='coerce')
Cities_DF["Wind Speed"] = pd.to_numeric(Cities_DF["Wind Speed(mph)"],errors='coerce')
Cities_DF["Date"] = pd.to_numeric(Cities_DF["Date"],errors='coerce')

Cities_DF.describe()
# Out:
#                Date         Lat         Lng  Max Temp(%)    Humidity  \
# count  5.700000e+02  570.000000  570.000000   570.000000  570.000000
# mean   1.638568e+09   20.084131   17.974090    51.612404   73.671930
# std    2.014701e+02   33.475683   91.060807    29.491361   19.140295
# min    1.638567e+09  -54.800000 -179.166700   -48.620000   15.000000
# 25%    1.638568e+09   -7.206450  -63.194600    33.330000   64.000000
# 50%    1.638568e+09   22.426100   24.005000    61.145000   77.000000
# 75%    1.638568e+09   49.008200   98.237500    76.252500   88.750000
# max    1.638568e+09   78.218600  177.483300    91.380000  100.000000
#
#        Cloudiness(F)  Wind Speed
# count     570.000000  570.000000
# mean       58.000000    7.777912
# std        39.734311    5.638997
# min         0.000000    0.000000
# 25%        17.000000    3.440000
# 50%        75.000000    6.645000
# 75%        98.750000   11.120000
# max       100.000000   32.210000

# %%
# Get index names for humidity > 100%
index_names = Cities_DF[Cities_DF['Humidity'] >= 100].index

#drop these rows
Cities_DF.drop(index_names,inplace=True)
Cities_DF
# Out:
#                City Temperature(F) Humidity(%) Cloudiness(%) Wind Speed(mph)  \
# 0             vaini          82.56          83            20            11.5
# 1          saleaula
# 2             korla          25.41          52            65            2.73
# 3       belaya gora         -19.59          97           100            2.37
# 4          cidreira          68.83          77            43           19.86
# ..              ...            ...         ...           ...             ...
# 613           ilebo          71.58          95           100             1.1
# 614              uk
# 615  fredericksburg          53.02          47             1            1.99
# 616     villa maria          78.26          40            93            7.38
# 617     casa branca          83.23          65            30            7.99
#
#     Latitude Longitude          Date      Lat       Lng  Max Temp(%)  \
# 0      -21.2    -175.2  1.638567e+09 -21.2000 -175.2000        82.56
# 1                                NaN      NaN       NaN          NaN
# 2    41.7597   86.1469  1.638567e+09  41.7597   86.1469        25.41
# 3    68.5333  146.4167  1.638567e+09  68.5333  146.4167       -19.59
# 4   -30.1811  -50.2056  1.638567e+09 -30.1811  -50.2056        68.83
# ..       ...       ...           ...      ...       ...          ...
# 613  -4.3167   20.5833  1.638568e+09  -4.3167   20.5833        71.58
# 614                              NaN      NaN       NaN          NaN
# 615  38.3032  -77.4605  1.638568e+09  38.3032  -77.4605        53.02
# 616 -32.4075  -63.2402  1.638568e+09 -32.4075  -63.2402        78.26
# 617 -21.7739  -47.0864  1.638568e+09 -21.7739  -47.0864        83.23
#
#      Humidity  Cloudiness(F)  Wind Speed
# 0        83.0           20.0       11.50
# 1         NaN            NaN         NaN
# 2        52.0           65.0        2.73
# 3        97.0          100.0        2.37
# 4        77.0           43.0       19.86
# ..        ...            ...         ...
# 613      95.0          100.0        1.10
# 614       NaN            NaN         NaN
# 615      47.0            1.0        1.99
# 616      40.0           93.0        7.38
# 617      65.0           30.0        7.99
#
# [610 rows x 14 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".


# Get index names for humidity > 100%
index_names = Cities_DF[Cities_DF['Humidity'] >= 100].index

#drop these rows
clean_city_data = Cities_DF.drop(index_names,inplace=False)
clean_city_data
# Out:
#                City Temperature(F) Humidity(%) Cloudiness(%) Wind Speed(mph)  \
# 0             vaini          82.56          83            20            11.5
# 1          saleaula
# 2             korla          25.41          52            65            2.73
# 3       belaya gora         -19.59          97           100            2.37
# 4          cidreira          68.83          77            43           19.86
# ..              ...            ...         ...           ...             ...
# 613           ilebo          71.58          95           100             1.1
# 614              uk
# 615  fredericksburg          53.02          47             1            1.99
# 616     villa maria          78.26          40            93            7.38
# 617     casa branca          83.23          65            30            7.99
#
#     Latitude Longitude          Date      Lat       Lng  Max Temp(%)  \
# 0      -21.2    -175.2  1.638567e+09 -21.2000 -175.2000        82.56
# 1                                NaN      NaN       NaN          NaN
# 2    41.7597   86.1469  1.638567e+09  41.7597   86.1469        25.41
# 3    68.5333  146.4167  1.638567e+09  68.5333  146.4167       -19.59
# 4   -30.1811  -50.2056  1.638567e+09 -30.1811  -50.2056        68.83
# ..       ...       ...           ...      ...       ...          ...
# 613  -4.3167   20.5833  1.638568e+09  -4.3167   20.5833        71.58
# 614                              NaN      NaN       NaN          NaN
# 615  38.3032  -77.4605  1.638568e+09  38.3032  -77.4605        53.02
# 616 -32.4075  -63.2402  1.638568e+09 -32.4075  -63.2402        78.26
# 617 -21.7739  -47.0864  1.638568e+09 -21.7739  -47.0864        83.23
#
#      Humidity  Cloudiness(F)  Wind Speed
# 0        83.0           20.0       11.50
# 1         NaN            NaN         NaN
# 2        52.0           65.0        2.73
# 3        97.0          100.0        2.37
# 4        77.0           43.0       19.86
# ..        ...            ...         ...
# 613      95.0          100.0        1.10
# 614       NaN            NaN         NaN
# 615      47.0            1.0        1.99
# 616      40.0           93.0        7.38
# 617      65.0           30.0        7.99
#
# [610 rows x 14 columns]

# %%
clean_city_data.dtypes
# Out:
# City                object
# Temperature(F)      object
# Humidity(%)         object
# Cloudiness(%)       object
# Wind Speed(mph)     object
# Latitude            object
# Longitude           object
# Date               float64
# Lat                float64
# Lng                float64
# Max Temp(%)        float64
# Humidity           float64
# Cloudiness(F)      float64
# Wind Speed         float64
# dtype: object

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Latitude vs Temperature Plot
plt.title("City Latitude vs Temperature(F)")
plt.xlabel("Latitude")
plt.ylabel("Temperature(F)")
plt.grid()

plt.scatter(clean_city_data["Lat"],clean_city_data["Max Temp(%)"],edgecolors="black")
plt.savefig(f'../output_data/temp.png')
plt.show()

# %% [markdown]
# Latitude vs Temperature Scatter Plot Insights
# The plot maps 'cities' temperature against their latitude. The curve shows temperature increasing near the equator and dropping further away. The plot shows highers temperatures to right of the equator due to summer in northern hemisphere

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Latitude vs Humidity Plot
plt.title("City Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.grid()

plt.scatter(clean_city_data["Lat"],clean_city_data["Humidity"],edgecolors="black")
plt.savefig(f'../output_data/humidity.png')
plt.show()

# %% [markdown]
# Latitude vs Humidity Scatter Plot Insights
# The plot maps 'cities' humidity against their latitude. There is no corelation between humidity and latitude

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#Latitude vs Cloudiness Plot
plt.title("City Latitude vs Cloudiness(%)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.grid()

plt.scatter(clean_city_data["Lat"],clean_city_data["Cloudiness(F)"],edgecolors="black")

plt.savefig(f'../output_data/cloudiness.png')
plt.show()

# %% [markdown]
# Latitude vs Cloudiness Scatter Plot Insights
# The plot maps 'cities' cloudiness against their latitude. Cities selected randomly
#
# There is no obvious corelation between cloudiness and latitude. The plots are dense around 0% and 100% cloudiness

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Latitude vs Wind Speed Plot
plt.title("City Latitude vs Wind Speed(mph)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(mph)")
plt.grid()

plt.scatter(clean_city_data["Lat"],clean_city_data["Wind Speed"],edgecolors="black")
plt.savefig(f'../output_data/wind.png')
plt.show()

# %% [markdown]
# Latitude vs Wind Speed Scatter Plot Insights
# The plot maps 'cities' Wind Speed against their latitude. Cities selected randomly
#
# There is no obvious corelation between Windspeed and latitude. The plots are dense around 0to 20 mph windspeed

# %% [markdown]
# ## Linear Regression

# %%
#Create Northern and Southers Hemisphere Data Frames
north_df = Cities_DF.loc[Cities_DF["Lat"] > 0]
south_df = Cities_DF.loc[Cities_DF["Lat"] < 0]

# %%
#create Linear regression function
def linearreg(x_values,y_values,EQplotx,EQploty,y_label):
    (slope,intercept,rvalue,pvalue,stderr) = linregress(x_values,y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    print(f'The r square if {rvalue}')
    print(line_eq)
    plt.annotate(line_eq,(EQplotx,EQploty),fontsize=10,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(f'{y_label}')
    plt.grid()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#set the data sets
x_values = north_df["Lat"]
y_values = north_df["Max Temp(%)"]

#position equation
EQplotx  = 0
EQploty = -40

y_label = "Temperature (F)"
plt.title(f'Northern Hemishphere Latitude vs Temp')
          
linearreg(x_values,y_values,EQplotx,EQploty,y_label)

#save file
plt.savefig(f'../output_data/Northern Hemisphere Latitude vs Temp.png')
plt.show()
# Out:
# The r square if -0.8687064249124591
# y = -1.3x + 93.15

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#set the data sets
x_values = south_df["Lat"]
y_values = south_df["Max Temp(%)"]

#position equation
EQplotx  = -55
EQploty = 85

y_label = "Temperature (F)"
plt.title(f'Southern Hemishphere Latitude vs Temp')
          
linearreg(x_values,y_values,EQplotx,EQploty,y_label)

#save file
plt.savefig(f'../output_data/Southern Hemisphere Latitude vs Temp.png')
plt.show()
# Out:
# The r square if 0.6553140854442211
# y = 0.42x + 80.83

# %% [markdown]
# Northern/Southern vs Temp Linear Regression Insights
#
# The plot maps Northern and Southern 'cities' Temperature against their latitude. Cities selected randomly
#
# There is strong corelation between distance from the equator temperature. The closer the equator, the higher the temperature

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#set the data sets
x_values = north_df["Lat"]
y_values = north_df["Humidity"]

#position equation
EQplotx  = 50
EQploty = 15

y_label = "Humidity (%)"
plt.title(f'Northern Hemishphere Latitude vs Humidity')
          
linearreg(x_values,y_values,EQplotx,EQploty,y_label)

#save file
plt.savefig(f'../output_data/Northern Hemisphere Latitude vs Humidity.png')
plt.show()
# Out:
# The r square if 0.30891476307544147
# y = 0.32x + 58.96

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#set the data sets
x_values = south_df["Lat"]
y_values = south_df["Humidity"]

#position equation
EQplotx  = -20
EQploty = 30

y_label = "Humidity (%)"
plt.title(f'Southern Hemishphere Latitude vs Humidity')
          
linearreg(x_values,y_values,EQplotx,EQploty,y_label)

#save file
plt.savefig(f'../output_data/Southern Hemisphere Latitude vs Humidity.png')
plt.show()
# Out:
# The r square if 0.39963757688948476
# y = 0.43x + 85.15

# %% [markdown]
# Northern/Southern vs Humidity Linear Regression Insights
#
# The plot maps Northern and Southern 'cities' Humidity against their latitude. Cities selected randomly
#
# There is no corelation between latitude and humidity

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#set the data sets
x_values = north_df["Lat"]
y_values = north_df["Cloudiness(F)"]

#position equation
EQplotx  = 50
EQploty = 25

y_label = "Cloudiness (F)"
plt.title(f'Northern Hemishphere Latitude vs Cloudiness')
          
linearreg(x_values,y_values,EQplotx,EQploty,y_label)

#save file
plt.savefig(f'../output_data/Northern Hemisphere Latitude vs Cloudiness.png')
plt.show()
# Out:
# The r square if 0.21961126688000715
# y = 0.44x + 38.7

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#set the data sets
x_values = south_df["Lat"]
y_values = south_df["Cloudiness(F)"]

#position equation
EQplotx  = -55
EQploty = 60

y_label = "Cloudiness (F)"
plt.title(f'Southern Hemishphere Latitude vs Cloudiness')
          
linearreg(x_values,y_values,EQplotx,EQploty,y_label)

#save file
plt.savefig(f'../output_data/Southern Hemisphere Latitude vs Cloudiness.png')
plt.show()
# Out:
# The r square if 0.19783330572734323
# y = 0.55x + 72.02

# %% [markdown]
# Northern/Southern Latitude vs Cloudiness Linear Regression Insights
#
# The plot maps Northern and Southern 'cities' Cloudiness against their latitude. Cities selected randomly
#
# There is no corelation between latitude and cloudiness

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#set the data sets
x_values = north_df["Lat"]
y_values = north_df["Wind Speed"]

#position equation
EQplotx  = 5
EQploty = 25

y_label = "Cloudiness (F)"
plt.title(f'Northern Hemishphere Latitude vs Wind Speed')
          
linearreg(x_values,y_values,EQplotx,EQploty,y_label)

#save file
plt.savefig(f'../output_data/Northern Hemisphere Latitude vs Wind Speed.png')
plt.show()
# Out:
# The r square if 0.2169214257234315
# y = 0.06x + 5.59

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#set the data sets
x_values = south_df["Lat"]
y_values = south_df["Wind Speed"]

#position equation
EQplotx  = -15
EQploty = 25

y_label = "Cloudiness (F)"
plt.title(f'Southern Hemishphere Latitude vs Wind Speed')
          
linearreg(x_values,y_values,EQplotx,EQploty,y_label)

#save file
plt.savefig(f'../output_data/Southern Hemisphere Latitude vs Wind Speed.png')
plt.show()
# Out:
# The r square if -0.3070553806782465
# y = -0.12x + 5.11

# %% [markdown]
# Northern/Southern Latitude vs Windspeed Linear Regression Insights
#
# The plot maps Northern and Southern 'cities' Wind Speed against their latitude. Cities selected randomly
#
# There is no corelation between latitude and wind speed
